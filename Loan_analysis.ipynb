# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('SBANational.csv')
df
# Out:
# C:\Users\NOOR\AppData\Local\Temp\ipykernel_11156\814572557.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('SBANational.csv')
#         LoanNr_ChkDgt                            Name             City State  \
# 0          1000014003                  ABC HOBBYCRAFT       EVANSVILLE    IN
# 1          1000024006     LANDMARK BAR & GRILLE (THE)        NEW PARIS    IN
# 2          1000034009           WHITLOCK DDS, TODD M.      BLOOMINGTON    IN
# 3          1000044001   BIG BUCKS PAWN & JEWELRY, LLC     BROKEN ARROW    OK
# 4          1000054004     ANASTASIA CONFECTIONS, INC.          ORLANDO    FL
# ...               ...                             ...              ...   ...
# 899159     9995573004                    FABRIC FARMS  UPPER ARLINGTON    OH
# 899160     9995603000                    FABRIC FARMS         COLUMBUS    OH
# 899161     9995613003    RADCO MANUFACTURING CO.,INC.      SANTA MARIA    CA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899164 entries, 0 to 899163
# Data columns (total 27 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   LoanNr_ChkDgt      899164 non-null  int64
#  1   Name               899150 non-null  object
#  2   City               899134 non-null  object
#  3   State              899150 non-null  object
#  4   Zip                899164 non-null  int64
#  5   Bank               897605 non-null  object
#  6   BankState          897598 non-null  object
#  7   NAICS              899164 non-null  int64
#  8   ApprovalDate       899164 non-null  object
#  9   ApprovalFY         899164 non-null  object
#  10  Term               899164 non-null  int64
#  11  NoEmp              899164 non-null  int64
#  12  NewExist           899028 non-null  float64
#  13  CreateJob          899164 non-null  int64
#  14  RetainedJob        899164 non-null  int64
# ...

# %%
df.describe()
# Out:
#        LoanNr_ChkDgt            Zip          NAICS           Term  \
# count   8.991640e+05  899164.000000  899164.000000  899164.000000
# mean    4.772612e+09   53804.391241  398660.950146     110.773078
# std     2.538175e+09   31184.159152  263318.312759      78.857305
# min     1.000014e+09       0.000000       0.000000       0.000000
# 25%     2.589758e+09   27587.000000  235210.000000      60.000000
# 50%     4.361439e+09   55410.000000  445310.000000      84.000000
# 75%     6.904627e+09   83704.000000  561730.000000     120.000000
# max     9.996003e+09   99999.000000  928120.000000     569.000000
#
#                NoEmp       NewExist      CreateJob    RetainedJob  \
# count  899164.000000  899028.000000  899164.000000  899164.000000
# mean       11.411353       1.280404       8.430376      10.797257
# std        74.108196       0.451750     236.688165     237.120600
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# LoanNr_ChkDgt             0
# Name                     14
# City                     30
# State                    14
# Zip                       0
# Bank                   1559
# BankState              1566
# NAICS                     0
# ApprovalDate              0
# ApprovalFY                0
# Term                      0
# NoEmp                     0
# NewExist                136
# CreateJob                 0
# RetainedJob               0
# FranchiseCode             0
# UrbanRural                0
# RevLineCr              4528
# LowDoc                 2582
# ChgOffDate           736465
# DisbursementDate       2368
# DisbursementGross         0
# BalanceGross              0
# MIS_Status             1997
# ChgOffPrinGr              0
# GrAppv                    0
# SBA_Appv                  0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['LoanNr_ChkDgt', 'Name', 'City', 'State', 'Zip', 'Bank', 'BankState',
#        'NAICS', 'ApprovalDate', 'ApprovalFY', 'Term', 'NoEmp', 'NewExist',
#        'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural', 'RevLineCr',
#        'LowDoc', 'ChgOffDate', 'DisbursementDate', 'DisbursementGross',
#        'BalanceGross', 'MIS_Status', 'ChgOffPrinGr', 'GrAppv', 'SBA_Appv'],
#       dtype='object')

# %%
df=df.dropna(subset=['Name','City','State'])

# %%
df.shape
# Out:
# (899106, 27)

# %%
df.columns = df.columns.str.strip()

# %%
# df.head()

df.columns
# Out:
# Index(['LoanNr_ChkDgt', 'Name', 'City', 'State', 'Zip', 'Bank', 'BankState',
#        'NAICS', 'ApprovalDate', 'ApprovalFY', 'Term', 'NoEmp', 'NewExist',
#        'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural', 'RevLineCr',
#        'LowDoc', 'ChgOffDate', 'DisbursementDate', 'DisbursementGross',
#        'BalanceGross', 'MIS_Status', 'ChgOffPrinGr', 'GrAppv', 'SBA_Appv'],
#       dtype='object')

# %%
df = df.drop(columns=['ChgOffDate'])
df
# Out:
#         LoanNr_ChkDgt                            Name             City State  \
# 0          1000014003                  ABC HOBBYCRAFT       EVANSVILLE    IN
# 1          1000024006     LANDMARK BAR & GRILLE (THE)        NEW PARIS    IN
# 2          1000034009           WHITLOCK DDS, TODD M.      BLOOMINGTON    IN
# 3          1000044001   BIG BUCKS PAWN & JEWELRY, LLC     BROKEN ARROW    OK
# 4          1000054004     ANASTASIA CONFECTIONS, INC.          ORLANDO    FL
# ...               ...                             ...              ...   ...
# 899159     9995573004                    FABRIC FARMS  UPPER ARLINGTON    OH
# 899160     9995603000                    FABRIC FARMS         COLUMBUS    OH
# 899161     9995613003    RADCO MANUFACTURING CO.,INC.      SANTA MARIA    CA
# 899162     9995973006           MARUTAMA HAWAII, INC.         HONOLULU    HI
# 899163     9996003010  PACIFIC TRADEWINDS FAN & LIGHT           KAILUA    HI
#
# ...

# %%
print(df.isnull().sum())
# Out:
# LoanNr_ChkDgt           0
# Name                    0
# City                    0
# State                   0
# Zip                     0
# Bank                 1556
# BankState            1563
# NAICS                   0
# ApprovalDate            0
# ApprovalFY              0
# Term                    0
# NoEmp                   0
# NewExist              136
# CreateJob               0
# RetainedJob             0
# FranchiseCode           0
# UrbanRural              0
# RevLineCr            4528
# LowDoc               2582
# DisbursementDate     2367
# DisbursementGross       0
# BalanceGross            0
# MIS_Status           1996
# ChgOffPrinGr            0
# GrAppv                  0
# SBA_Appv                0
# dtype: int64

# %%
df['Bank'].isnull().any()
# Out:
# np.True_

# %%
df[df['Bank'].isnull()]
# Out:
#         LoanNr_ChkDgt                            Name        City State  \
# 407        1003113008        MOUNTVILLE WALL PAPER CO  MOUNTVILLE    PA
# 611        1004503009            SMITHFIELD GLASS INC   DANIELSON    CT
# 680        1004933009         TAYLOR BROTHERS COMPANY   CLEVELAND    OH
# 740        1005273003     GENERAL SOLAR COMPANY, INC.  SIOUX CITY    IA
# 6569       1044653002               SON'S PARTY STORE    KENTWOOD    MI
# ...               ...                             ...         ...   ...
# 888537     9772941008  INTERNATIONAL PREHEATER COMPAN     SEATTLE    WA
# 888681     9775961009   MANDARIN INTERNATIONAL CO INC     SEATTLE    WA
# 897114     9950351001                        CLUB 191  PORTSMOUTH    IA
# 897474     9958533004        ROMES CONSTRUCTION, INC.  FORT WAYNE    IN
# 897749     9964143001             KEN-TEX SALES, INC.      DALLAS    TX
#
#           Zip Bank BankState   NAICS ApprovalDate ApprovalFY  ...  UrbanRural  \
# ...

# %%
df[df['Bank'].isnull()].index
# Out:
# Index([   407,    611,    680,    740,   6569,   9602,  10412,  11824,  13507,
#         15254,
#        ...
#        880178, 880844, 885560, 886790, 888026, 888537, 888681, 897114, 897474,
#        897749],
#       dtype='int64', length=1556)

# %%
df['Bank'].fillna('Unknown Bank', inplace=True)
df['BankState'].fillna('Unknown State', inplace=True)
df
# Out:
# C:\Users\NOOR\AppData\Local\Temp\ipykernel_11156\2924351368.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Bank'].fillna('Unknown Bank', inplace=True)
# C:\Users\NOOR\AppData\Local\Temp\ipykernel_11156\2924351368.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df[['Bank','BankState']].isnull().sum()
# Out:
# Bank         0
# BankState    0
# dtype: int64

# %%
df['NewExist'].fillna(df['NewExist'].mode()[0], inplace=True)
df
# Out:
# C:\Users\NOOR\AppData\Local\Temp\ipykernel_11156\1176448887.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['NewExist'].fillna(df['NewExist'].mode()[0], inplace=True)
#         LoanNr_ChkDgt                            Name             City State  \
# 0          1000014003                  ABC HOBBYCRAFT       EVANSVILLE    IN
# 1          1000024006     LANDMARK BAR & GRILLE (THE)        NEW PARIS    IN
# 2          1000034009           WHITLOCK DDS, TODD M.      BLOOMINGTON    IN
# ...

# %%
df['NewExist'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['RevLineCr'].isnull().sum()
# Out:
# np.int64(4528)

# %%
df['RevLineCr'].fillna('N', inplace=True)
# Out:
# C:\Users\NOOR\AppData\Local\Temp\ipykernel_11156\883877999.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RevLineCr'].fillna('N', inplace=True)

# %%
df['RevLineCr'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['LowDoc'].fillna('N', inplace=True)
# Out:
# C:\Users\NOOR\AppData\Local\Temp\ipykernel_11156\1670739153.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LowDoc'].fillna('N', inplace=True)

# %%
df['LowDoc'].isnull().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#         LoanNr_ChkDgt                            Name             City State  \
# 0          1000014003                  ABC HOBBYCRAFT       EVANSVILLE    IN
# 1          1000024006     LANDMARK BAR & GRILLE (THE)        NEW PARIS    IN
# 2          1000034009           WHITLOCK DDS, TODD M.      BLOOMINGTON    IN
# 3          1000044001   BIG BUCKS PAWN & JEWELRY, LLC     BROKEN ARROW    OK
# 4          1000054004     ANASTASIA CONFECTIONS, INC.          ORLANDO    FL
# ...               ...                             ...              ...   ...
# 899159     9995573004                    FABRIC FARMS  UPPER ARLINGTON    OH
# 899160     9995603000                    FABRIC FARMS         COLUMBUS    OH
# 899161     9995613003    RADCO MANUFACTURING CO.,INC.      SANTA MARIA    CA
# 899162     9995973006           MARUTAMA HAWAII, INC.         HONOLULU    HI
# 899163     9996003010  PACIFIC TRADEWINDS FAN & LIGHT           KAILUA    HI
#
# ...

# %%
df.iloc[5:6]
# Out:
#    LoanNr_ChkDgt                            Name        City State   Zip  \
# 5     1000084002  B&T SCREW MACHINE COMPANY, INC  PLAINVILLE    CT  6062
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 5  TD BANK, NATIONAL ASSOCIATION        DE  332721    28-Feb-97       1997
#
#    ...  UrbanRural  RevLineCr  LowDoc  DisbursementDate  DisbursementGross  \
# 5  ...           0          N       N         30-Jun-97       $517,000.00
#
#    BalanceGross  MIS_Status ChgOffPrinGr        GrAppv      SBA_Appv
# 5        $0.00        P I F       $0.00   $517,000.00   $387,750.00
#
# [1 rows x 26 columns]

# %%
df['MIS_Status'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\NOOR\AppData\Local\Temp\ipykernel_11156\2192162405.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MIS_Status'].fillna('Unknown', inplace=True)

# %%
print(df['MIS_Status'].isnull().sum())
# Out:
# 0

# %%
print(df['MIS_Status'].value_counts())
# Out:
# MIS_Status
# P I F      739555
# CHGOFF     157555
# Unknown      1996
# Name: count, dtype: int64

# %%
sns.countplot(x='MIS_Status', data=df)
plt.title("Loan Outcome: Paid vs Charged Off")
plt.show()
